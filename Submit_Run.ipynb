# %%
from azureml.core import ScriptRunConfig, RunConfiguration
from azureml.core import Workspace, Experiment

# %%
ws = Workspace.from_config(path = './aml_config/PredictiveMaintenanceWSConfig.json')
# Out:
# Found the config file in: D:\Projects\PredictiveMaintenance\aml_config\PredictiveMaintenanceWSConfig.json

# %%
exp = Experiment(name = 'TrainModel', workspace = ws)

# %%
#run_config = RunConfiguration.load(name = 'local', path = '.') 
run_config = RunConfiguration.load(name = 'amlcompute', path = '.') 
#run_config = RunConfiguration.load(name = 'cluster', path = '.') # `cluster` Compute Target should be created within Azure ML Workspace

# %%
print(run_config)
# Out:
# <azureml.core.runconfig.RunConfiguration object at 0x0000026F3D320CC0>

# %%
script_run_config = ScriptRunConfig(source_directory = '.', script = 'train.py', run_config = run_config)

# %%
run = exp.submit(script_run_config)

# %%
print(run.get_portal_url())
# Out:
# https://mlworkspace.azure.ai/portal/subscriptions/f0ead8e9-14fb-4521-b2cb-4378927736a8/resourceGroups/PredictiveMaintenanceResourceGroup/providers/Microsoft.MachineLearningServices/workspaces/PredictiveMaintenanceWS/experiments/TrainModel/runs/TrainModel_1544414263424

# %%
import time
run.log('Starting Submission', time.asctime(time.localtime(time.time())))

# %%
run.wait_for_completion(show_output = True)
# Out:
# RunId: TrainModel_1544414263424
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2018/12/10 03:57:52 Using acb_vol_90683e70-b909-49eb-be35-4c584764c9b0 as the home volume
# 2018/12/10 03:57:52 Creating Docker network: acb_default_network, driver: 'bridge'
# 2018/12/10 03:57:52 Successfully set up Docker network: acb_default_network
# 2018/12/10 03:57:52 Setting up Docker configuration...
# 2018/12/10 03:57:53 Successfully set up Docker configuration
# 2018/12/10 03:57:53 Logging in to registry: predictiacrawjhhhpu.azurecr.io
# 2018/12/10 03:57:54 Successfully logged in
# 2018/12/10 03:57:54 Executing step ID: acb_step_0. Working directory: '', Network: 'acb_default_network'
# 2018/12/10 03:57:54 Obtaining source code and scanning for dependencies...
# 2018/12/10 03:57:55 Successfully obtained source code and scanned for dependencies
# Sending build context to Docker daemon  1.761MB
#
# Step 1/13 : FROM mcr.microsoft.com/azureml/base:0.2.0
# 0.2.0: Pulling from azureml/base
# 3b37166ec614: Pulling fs layer
# 504facff238f: Pulling fs layer
# ebbcacd28e10: Pulling fs layer
# c7fb3351ecad: Pulling fs layer
# 2e3debadcbf7: Pulling fs layer
# 7ff5eaad8a49: Pulling fs layer
# 8697dd9e92dc: Pulling fs layer
# 112403772eb3: Pulling fs layer
# 0431a9485aa5: Pulling fs layer
# a8ab5d81aeba: Pulling fs layer
# c7fb3351ecad: Waiting
# 2e3debadcbf7: Waiting
# 7ff5eaad8a49: Waiting
# 8697dd9e92dc: Waiting
# 112403772eb3: Waiting
# 0431a9485aa5: Waiting
# a8ab5d81aeba: Waiting
# 504facff238f: Download complete
# ebbcacd28e10: Download complete
# 3b37166ec614: Download complete
# 2e3debadcbf7: Verifying Checksum
# 2e3debadcbf7: Download complete
# c7fb3351ecad: Verifying Checksum
# c7fb3351ecad: Download complete
# 7ff5eaad8a49: Verifying Checksum
# 7ff5eaad8a49: Download complete
# 3b37166ec614: Pull complete
# 504facff238f: Pull complete
# 8697dd9e92dc: Verifying Checksum
# 8697dd9e92dc: Download complete
# ebbcacd28e10: Pull complete
# c7fb3351ecad: Pull complete
# 2e3debadcbf7: Pull complete
# 7ff5eaad8a49: Pull complete
# 112403772eb3: Verifying Checksum
# 112403772eb3: Download complete
# 8697dd9e92dc: Pull complete
# a8ab5d81aeba: Verifying Checksum
# a8ab5d81aeba: Download complete
# 0431a9485aa5: Verifying Checksum
# 0431a9485aa5: Download complete
# 112403772eb3: Pull complete
# 0431a9485aa5: Pull complete
# a8ab5d81aeba: Pull complete
# Digest: sha256:bddfac8e9a4406c13f314cefefa24f3f67e959a8d8b26067096f7ade6f02ef12
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:0.2.0
#  ---> b588362a9d48
# Step 2/13 : USER root
#  ---> Running in 6747111b776e
# Removing intermediate container 6747111b776e
#  ---> bae6d322af60
# Step 3/13 : RUN mkdir -p $HOME/.cache
#  ---> Running in f22987399611
# Removing intermediate container f22987399611
#  ---> 24eab7d5bf67
# Step 4/13 : WORKDIR /
#  ---> Running in 6136420c877d
# Removing intermediate container 6136420c877d
#  ---> 7c4a2e6b9a26
# Step 5/13 : COPY azureml-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 2ebf668e8a2f
# Step 6/13 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.0; then conda install conda==4.4.11; fi
#  ---> Running in dca19306a8cf
# Removing intermediate container dca19306a8cf
#  ---> a1bc44996942
# Step 7/13 : COPY azureml-setup/mutated_conda_dependencies.yml azureml-setup/mutated_conda_dependencies.yml
#  ---> 296d2b3d4c5d
# Step 8/13 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_90b783527e5b3ab85021085858275133 -f azureml-setup/mutated_conda_dependencies.yml && ldconfig
#  ---> Running in b7c57e6df91f
# Solving environment: ...working... done
#
# ca-certificates-2018 | 124 KB    |            |   0%
# ca-certificates-2018 | 124 KB    | ########## | 100%
#
# wheel-0.32.3         | 35 KB     |            |   0%
# wheel-0.32.3         | 35 KB     | ########## | 100%
#
# certifi-2018.10.15   | 139 KB    |            |   0%
# certifi-2018.10.15   | 139 KB    | ########## | 100%
#
# python-dateutil-2.7. | 275 KB    |            |   0%
# python-dateutil-2.7. | 275 KB    | ########## | 100%
#
# libstdcxx-ng-8.2.0   | 2.9 MB    |            |   0%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #######5   |  75%
# libstdcxx-ng-8.2.0   | 2.9 MB    | #########7 |  98%
# libstdcxx-ng-8.2.0   | 2.9 MB    | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | #########4 |  95%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# libsodium-1.0.16     | 302 KB    |            |   0%
# libsodium-1.0.16     | 302 KB    | #########5 |  96%
# libsodium-1.0.16     | 302 KB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# ncurses-6.1          | 958 KB    |            |   0%
# ncurses-6.1          | 958 KB    | #######8   |  79%
# ncurses-6.1          | 958 KB    | #########1 |  91%
# ncurses-6.1          | 958 KB    | ########## | 100%
#
# parso-0.3.1          | 114 KB    |            |   0%
# parso-0.3.1          | 114 KB    | ########## | 100%
#
# libedit-3.1.20170329 | 172 KB    |            |   0%
# libedit-3.1.20170329 | 172 KB    | ########## | 100%
#
# setuptools-40.6.2    | 604 KB    |            |   0%
# setuptools-40.6.2    | 604 KB    | ########6  |  87%
# setuptools-40.6.2    | 604 KB    | ########## | 100%
#
# pyzmq-17.1.2         | 454 KB    |            |   0%
# pyzmq-17.1.2         | 454 KB    | ########6  |  86%
# pyzmq-17.1.2         | 454 KB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# zeromq-4.2.5         | 567 KB    |            |   0%
# zeromq-4.2.5         | 567 KB    | #########5 |  95%
# zeromq-4.2.5         | 567 KB    | ########## | 100%
#
# openssl-1.1.1a       | 5.0 MB    |            |   0%
# openssl-1.1.1a       | 5.0 MB    | #######5   |  76%
# openssl-1.1.1a       | 5.0 MB    | #########5 |  96%
# openssl-1.1.1a       | 5.0 MB    | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# pip-18.1             | 1.8 MB    |            |   0%
# pip-18.1             | 1.8 MB    | #######8   |  78%
# pip-18.1             | 1.8 MB    | #########1 |  92%
# pip-18.1             | 1.8 MB    | ########## | 100%
#
# sqlite-3.25.3        | 1.9 MB    |            |   0%
# sqlite-3.25.3        | 1.9 MB    | ########   |  81%
# sqlite-3.25.3        | 1.9 MB    | ########## | 100%
#
# ipykernel-4.6.1      | 139 KB    |            |   0%
# ipykernel-4.6.1      | 139 KB    | ########## | 100%
#
# libgcc-ng-8.2.0      | 7.6 MB    |            |   0%
# libgcc-ng-8.2.0      | 7.6 MB    | ######6    |  67%
# libgcc-ng-8.2.0      | 7.6 MB    | ########6  |  87%
# libgcc-ng-8.2.0      | 7.6 MB    | ########## | 100%
#
# jupyter_core-4.4.0   | 63 KB     |            |   0%
# jupyter_core-4.4.0   | 63 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# python-3.6.7         | 34.3 MB   |            |   0%
# python-3.6.7         | 34.3 MB   | #4         |  14%
# python-3.6.7         | 34.3 MB   | ###3       |  34%
# python-3.6.7         | 34.3 MB   | #####6     |  56%
# python-3.6.7         | 34.3 MB   | #######5   |  75%
# python-3.6.7         | 34.3 MB   | ########9  |  90%
# python-3.6.7         | 34.3 MB   | ########## | 100%
#
# jupyter_client-5.2.3 | 124 KB    |            |   0%
# jupyter_client-5.2.3 | 124 KB    | ########## | 100%
#
# wcwidth-0.1.7        | 25 KB     |            |   0%
# wcwidth-0.1.7        | 25 KB     | ########## | 100%
#
# traitlets-4.3.2      | 133 KB    |            |   0%
# traitlets-4.3.2      | 133 KB    | ########## | 100%
#
# jedi-0.13.1          | 229 KB    |            |   0%
# jedi-0.13.1          | 229 KB    | ########## | 100%
#
# ipython-7.2.0        | 1.0 MB    |            |   0%
# ipython-7.2.0        | 1.0 MB    | #######9   |  80%
# ipython-7.2.0        | 1.0 MB    | #########4 |  95%
# ipython-7.2.0        | 1.0 MB    | ########## | 100%
#
# backcall-0.1.0       | 19 KB     |            |   0%
# backcall-0.1.0       | 19 KB     | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | ########8  |  89%
# tk-8.6.8             | 3.1 MB    | #########8 |  99%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# pexpect-4.6.0        | 77 KB     |            |   0%
# pexpect-4.6.0        | 77 KB     | ########## | 100%
#
# readline-7.0         | 392 KB    |            |   0%
# readline-7.0         | 392 KB    | #########8 |  99%
# readline-7.0         | 392 KB    | ########## | 100%
#
# pygments-2.2.0       | 1.3 MB    |            |   0%
# pygments-2.2.0       | 1.3 MB    | #######8   |  79%
# pygments-2.2.0       | 1.3 MB    | #########3 |  94%
# pygments-2.2.0       | 1.3 MB    | ########## | 100%
# prompt_toolkit-2.0.7 | 482 KB    |            |   0%
# prompt_toolkit-2.0.7 | 482 KB    | ########7  |  87%
# prompt_toolkit-2.0.7 | 482 KB    | ########## | 100%
#
# tornado-5.1.1        | 663 KB    |            |   0%
# tornado-5.1.1        | 663 KB    | ########7  |  87%
# tornado-5.1.1        | 663 KB    | ########## | 100%
#
# decorator-4.3.0      | 15 KB     |            |   0%
# decorator-4.3.0      | 15 KB     | ########## | 100%
#
# six-1.11.0           | 21 KB     |            |   0%
# six-1.11.0           | 21 KB     | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting azureml-defaults (from -r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bb/4e/27a93da1484f06043f0a6b4d4f3e5ed7212c513eb0d2021cb434c4b2a29d/azureml_defaults-1.0.2-py2.py3-none-any.whl
# Collecting azureml.assets==1.0.0 from https://azuremldownloads.blob.core.windows.net/wheels/latest/azureml.assets-1.0.0-py3-none-any.whl?sv=2016-05-31&si=ro-2017&sr=c&sig=xnUdTm0B%2F%2FfknhTaRInBXyu2QTTt8wA3OsXwGVgU%2BJk%3D (from -r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 2))
#   Downloading https://azuremldownloads.blob.core.windows.net/wheels/latest/azureml.assets-1.0.0-py3-none-any.whl?sv=2016-05-31&si=ro-2017&sr=c&sig=xnUdTm0B%2F%2FfknhTaRInBXyu2QTTt8wA3OsXwGVgU%2BJk%3D
# Collecting pandas (from -r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/e1/d8/feeb346d41f181e83fba45224ab14a8d8af019b48af742e047f3845d8cff/pandas-0.23.4-cp36-cp36m-manylinux1_x86_64.whl (8.9MB)
# Collecting azureml-core==1.0.2.* (from azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f5/ce/3443d87ba4735de037003413063b7d5d77b00543b787c495b0ab682be254/azureml_core-1.0.2-py2.py3-none-any.whl (651kB)
# Collecting applicationinsights>=0.11.0 (from azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e3/c8/7848a0dd85158930b859eb8be1e38fc76a91f0a040d491723ebb356d7358/applicationinsights-0.11.7-py2.py3-none-any.whl (56kB)
# Collecting requests (from azureml.assets==1.0.0->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/ff/17/5cbb026005115301a8fb2f9b0e3e8d32313142fe8b617070e7baad20554f/requests-2.20.1-py2.py3-none-any.whl (57kB)
# Requirement already satisfied: python-dateutil>=2.5.0 in /azureml-envs/azureml_90b783527e5b3ab85021085858275133/lib/python3.6/site-packages (from pandas->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 3)) (2.7.5)
# Collecting numpy>=1.9.0 (from pandas->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/ff/7f/9d804d2348471c67a7d8b5f84f9bc59fd1cefa148986f2b74552f8573555/numpy-1.15.4-cp36-cp36m-manylinux1_x86_64.whl (13.9MB)
# Collecting pytz>=2011k (from pandas->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 3))
#   Downloading https://files.pythonhosted.org/packages/f8/0e/2365ddc010afb3d79147f1dd544e5ee24bf4ece58ab99b16fbb465ce6dc0/pytz-2018.7-py2.py3-none-any.whl (506kB)
# Collecting PyJWT (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting azure-mgmt-containerregistry>=2.0.0 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/35/d1/e8887811e8e5ab336e77db7cfb9f451bdae69a8ed97f53cc2cd11fdcac8f/azure_mgmt_containerregistry-2.4.0-py2.py3-none-any.whl (482kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/60/c7/99b33c53cf3f20a97a4c4bfd3ab66dcc93d99da0a97cc9597aa36ae6bb62/cryptography-2.4.2-cp34-abi3-manylinux1_x86_64.whl (2.1MB)
# Collecting backports.tempfile (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b4/5c/077f910632476281428fe254807952eb47ca78e720d059a46178c541e669/backports.tempfile-1.0-py2.py3-none-any.whl
# Collecting azure-cli-core>=2.0.38 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a1/f0/507c83334d7ee7d588fdd1210b6f470446077c62f3e22fdb955f9d3396f8/azure_cli_core-2.0.52-py2.py3-none-any.whl (106kB)
# Collecting azure-mgmt-storage>=1.5.0 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e8/d9/496b29857a252bc3fcc4bbda069c0eb64b537c8e8f7e342abb4053ba920f/azure_mgmt_storage-3.1.0-py2.py3-none-any.whl (696kB)
# Collecting azure-storage-common>=1.1.0 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/73/84/025ac436a6a1d5516d1a67887d7122b3b2ea04ba6b2d2c46fe949accb62b/azure_storage_common-1.4.0-py2.py3-none-any.whl (46kB)
# Collecting ruamel.yaml<=0.15.51,>=0.15.35 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d2/7f/9bb3ba89ceab600c4a0ea75d638ea945215ca3458ac6528e0e39fa3254e4/ruamel.yaml-0.15.51-cp36-cp36m-manylinux1_x86_64.whl (640kB)
# Collecting azure-storage-blob>=1.1.0 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f7/b7/9b20c39bf411e896d110d01f2551e6e7b397fde6eb06b07293fe29705d13/azure_storage_blob-1.4.0-py2.py3-none-any.whl (75kB)
# Collecting azure-mgmt-authorization>=0.40.0 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a1/71/9a20913e92771b3c23564f1bea54d376d09fb30a75585087c70b769d75c8/azure_mgmt_authorization-0.51.1-py2.py3-none-any.whl (111kB)
# Collecting SecretStorage<3.0.0 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a5/a5/0830cfe34a4cfd0d1c3c8b614ede1edb2aaf999091ac8548dd19cb352e79/SecretStorage-2.3.1.tar.gz
# Collecting ndg-httpsclient (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/fb/67/c2f508c00ed2a6911541494504b7cac16fe0b0473912568df65fd1801132/ndg_httpsclient-0.5.1-py3-none-any.whl
# Collecting msrest>=0.5.1 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d5/40/70e545b7a5b0509273c6fe981118fb64e389fe013504b1c22a24fec4d1d9/msrest-0.6.2-py2.py3-none-any.whl (81kB)
# Collecting azure-cli-profile>=2.0.26 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c2/d3/fdc722a1b61857250a76027d6d73a50182c6d85132ddd65600a8993574ce/azure_cli_profile-2.1.2-py2.py3-none-any.whl
# Collecting jsonpickle (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ca/ce/97404d5aeb58e6155c216825c81b50f6eca8a5345c582317ae48391878f8/jsonpickle-1.0-py2.py3-none-any.whl
# Collecting docker (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e1/58/938fbc7acd98302ca4872f5eab8ab811498e342ab5aec0c1609f22e0aeda/docker-3.6.0-py2.py3-none-any.whl (131kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_90b783527e5b3ab85021085858275133/lib/python3.6/site-packages (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1)) (1.11.0)
# Collecting msrestazure>=0.4.33 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/62/6e/c41d6e2db39f4c6b819cea5b47c36c0fa0e7a931cd39b4c5f19713d28fd1/msrestazure-0.5.1-py2.py3-none-any.whl
# Collecting azure-graphrbac>=0.40.0 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/da/a8/3d3d6fe8458b2b07bad10195c79928ea9ba87b5cc0c08903b387dd27c6f0/azure_graphrbac-0.53.0-py2.py3-none-any.whl (108kB)
# Collecting azure-mgmt-keyvault>=0.40.0 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/49/de/0d69aedae7c5f6428314640b65947203ab80409c12b5d4e66fb5b7a4182e/azure_mgmt_keyvault-1.1.0-py2.py3-none-any.whl (111kB)
# Collecting contextlib2 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a2/71/8273a7eeed0aff6a854237ab5453bc9aa67deb49df4832801c21f0ff3782/contextlib2-0.5.5-py2.py3-none-any.whl
# Collecting azure-mgmt-resource>=1.2.1 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/2b/26/c0cb69dfac2e5b7125db034045b8bcf937cf1e8d3df2009a87c33d0959f5/azure_mgmt_resource-2.0.0-py2.py3-none-any.whl (698kB)
# Collecting urllib3<1.24,>=1.23 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/bd/c9/6fdd990019071a4a32a5e7cb78a1d92c53851ef4f56f62a3486e6a7d8ffb/urllib3-1.23-py2.py3-none-any.whl (133kB)
# Collecting azure-common>=1.1.12 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ac/d3/055ce7ad06459a415ff9ca210e04c6cbb51bd6564815b7c8ac34bf5a1c39/azure_common-1.1.16-py2.py3-none-any.whl
# Collecting azure-storage-nspkg>=3.0.0 (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ba/f6/054ace7b01c6c21b3b95a83c3997f7d6539d939a2c08c4f27f779128a030/azure_storage_nspkg-3.1.0-py2.py3-none-any.whl
# Collecting pathspec (from azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/84/2a/bfee636b1e2f7d6e30dd74f49201ccfa5c3cf322d44929ecc6c137c486c5/pathspec-0.5.9.tar.gz
# Collecting chardet<3.1.0,>=3.0.2 (from requests->azureml.assets==1.0.0->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Collecting idna<2.8,>=2.5 (from requests->azureml.assets==1.0.0->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 2))
#   Downloading https://files.pythonhosted.org/packages/4b/2a/0276479a4b3caeb8a8c1af2f8e4355746a97fab05a372e4a2c6a6b876165/idna-2.7-py2.py3-none-any.whl (58kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_90b783527e5b3ab85021085858275133/lib/python3.6/site-packages (from requests->azureml.assets==1.0.0->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 2)) (2018.10.15)
# Collecting cffi!=1.11.3,>=1.7 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/6d/c0/47db8f624f3e4e2f3f27be03a93379d1ba16a1450a7b1aacfa0366e2c0dd/cffi-1.11.5-cp36-cp36m-manylinux1_x86_64.whl (421kB)
# Collecting asn1crypto>=0.21.0 (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/ea/cd/35485615f45f30a510576f1a56d1e0a7ad7bd8ab5ed7cdc600ef7cd06222/asn1crypto-0.24.0-py2.py3-none-any.whl (101kB)
# Collecting backports.weakref (from backports.tempfile->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/88/ec/f598b633c3d5ffe267aaada57d961c94fdfa183c5c3ebda2b6d151943db6/backports.weakref-1.0.post1-py2.py3-none-any.whl
# Collecting azure-cli-nspkg>=2.0.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/a7/85/601ef6484bf7a722daa76a4383c4ccfd4980b74ed6c2895392f53ed210d5/azure_cli_nspkg-3.0.3-py2.py3-none-any.whl
# Requirement already satisfied: pygments in /azureml-envs/azureml_90b783527e5b3ab85021085858275133/lib/python3.6/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1)) (2.2.0)
# Collecting argcomplete>=1.8.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/31/88/ba8d8684a8a27749250c66ff7c2b408fdbc29b50da61200338ff9b2607bf/argcomplete-1.9.4-py2.py3-none-any.whl
# Collecting humanfriendly>=4.7 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/79/1e/13d96248e3fcaa7777b61fa889feab44865c85e524bbd667acfa0d8b66e3/humanfriendly-4.17-py2.py3-none-any.whl (72kB)
# Requirement already satisfied: pip in /azureml-envs/azureml_90b783527e5b3ab85021085858275133/lib/python3.6/site-packages (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1)) (18.1)
# Collecting wheel==0.30.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/0c/80/16a85b47702a1f47a63c104c91abdd0a6704ee8ae3b4ce4afc49bc39f9d9/wheel-0.30.0-py2.py3-none-any.whl (49kB)
# Collecting colorama>=0.3.9 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/4f/a6/728666f39bfff1719fc94c481890b2106837da9318031f71a8424b662e12/colorama-0.4.1-py2.py3-none-any.whl
# Collecting adal>=1.2.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/2d/2f/14882b8dae0977e85577abde3065c141fb94dbb242adfb80e21797e4f7c9/adal-1.2.0-py2.py3-none-any.whl (52kB)
# Collecting pyyaml~=3.13 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9e/a3/1d13970c3f36777c583f136c136f804d70f500168edc1edea6daa7200769/PyYAML-3.13.tar.gz (270kB)
# Collecting azure-cli-telemetry (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/71/4c/da5ebe9300ecdc850031372f81229383c46a70e83dee8e77f58aa6fd0546/azure_cli_telemetry-1.0.0-py2.py3-none-any.whl
# Collecting pyopenssl>=17.1.0 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/96/af/9d29e6bd40823061aea2e0574ccb2fcf72bfd6130ce53d32773ec375458c/pyOpenSSL-18.0.0-py2.py3-none-any.whl (53kB)
# Collecting jmespath (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting knack==0.5.1 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/46/0a6d7471efcc519e392640f6933c0f644bbf602971e64797108292cb3623/knack-0.5.1-py2.py3-none-any.whl (50kB)
# Collecting tabulate<=0.8.2,>=0.7.7 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/12/c2/11d6845db5edf1295bc08b2f488cf5937806586afe42936c3f34c097ebdc/tabulate-0.8.2.tar.gz (45kB)
# Collecting paramiko>=2.0.8 (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/cf/ae/94e70d49044ccc234bfdba20114fa947d7ba6eb68a2e452d89b920e62227/paramiko-2.4.2-py2.py3-none-any.whl (193kB)
# Collecting antlr4-python3-runtime; python_version >= "3.0" (from azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/3e/96/aba01b2948ec67f237cd387c022820835ae0d8db5cab4bd404b351660b5e/antlr4-python3-runtime-4.7.1.tar.gz (111kB)
# Collecting pyasn1>=0.1.1 (from ndg-httpsclient->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/d1/a1/7790cc85db38daa874f6a2e6308131b9953feb1367f2ae2d1123bb93a9f5/pyasn1-0.4.4-py2.py3-none-any.whl (72kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.5.1->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/94/e7/c250d122992e1561690d9c0f7856dadb79d61fd4bdd0e598087dce607f6c/requests_oauthlib-1.0.0-py2.py3-none-any.whl
# Collecting isodate>=0.6.0 (from msrest>=0.5.1->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
# Collecting azure-cli-command-modules-nspkg>=2.0.0 (from azure-cli-profile>=2.0.26->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e6/c9/cdeeeabc550848e2a07caa66cba28aa057d23b6feaa824ceafd32c3f2226/azure_cli_command_modules_nspkg-2.0.2-py2.py3-none-any.whl
# Collecting docker-pycreds>=0.3.0 (from docker->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting websocket-client>=0.32.0 (from docker->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/26/2d/f749a5c82f6192d77ed061a38e02001afcba55fe8477336d26a950ab17ce/websocket_client-0.54.0-py2.py3-none-any.whl (200kB)
# Collecting azure-mgmt-nspkg>=2.0.0 (from azure-mgmt-keyvault>=0.40.0->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b3/c2/af4b47845f27dc7d206ed4908b9e580f8bc94a4b2f3956a0d87c40719d90/azure_mgmt_nspkg-3.0.2-py3-none-any.whl
# Collecting azure-nspkg>=2.0.0 (from azure-storage-nspkg>=3.0.0->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/c4/0c/c562be95a9a2ed52454f598571cf300b1114d0db2aa27f5b8ed3bb9cd0c0/azure_nspkg-3.0.2-py3-none-any.whl
# Collecting pycparser (from cffi!=1.11.3,>=1.7->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/68/9e/49196946aee219aead1290e00d1e7fdeab8567783e83e1b9ab5585e6206a/pycparser-2.19.tar.gz (158kB)
# Collecting portalocker==1.2.1 (from azure-cli-telemetry->azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/57/41/05e79e5516db1cc0c967b3202388cde729f871c871b0a07bf24ff11adfcf/portalocker-1.2.1-py2.py3-none-any.whl
# Collecting pynacl>=1.0.1 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/27/15/2cd0a203f318c2240b42cd9dd13c931ddd61067809fee3479f44f086103e/PyNaCl-1.3.0-cp34-abi3-manylinux1_x86_64.whl (759kB)
# Collecting bcrypt>=3.1.3 (from paramiko>=2.0.8->azure-cli-core>=2.0.38->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/b8/09/905ec939994e2c49dcffff72f823802557f166b3815ea54c1db3671eed42/bcrypt-3.1.4-cp36-cp36m-manylinux1_x86_64.whl (54kB)
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core==1.0.2.*->azureml-defaults->-r /azureml-setup/condaenv.lsb8k__h.requirements.txt (line 1))
#   Downloading https://files.pythonhosted.org/packages/e6/d1/ddd9cfea3e736399b97ded5c2dd62d1322adef4a72d816f1ed1049d6a179/oauthlib-2.1.0-py2.py3-none-any.whl (121kB)
# Building wheels for collected packages: SecretStorage, pathspec, pyyaml, tabulate, antlr4-python3-runtime, pycparser
#   Running setup.py bdist_wheel for SecretStorage: started
#   Running setup.py bdist_wheel for SecretStorage: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/4e/5b/1b/be8c8a830a0243af85b2946a0aece2c6743d7f7f946977ed67
#   Running setup.py bdist_wheel for pathspec: started
#   Running setup.py bdist_wheel for pathspec: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/45/cb/7e/ce6e6062c69446e39e328170524ca8213498bc66a74c6a210b
#   Running setup.py bdist_wheel for pyyaml: started
#   Running setup.py bdist_wheel for pyyaml: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/ad/da/0c/74eb680767247273e2cf2723482cb9c924fe70af57c334513f
#   Running setup.py bdist_wheel for tabulate: started
#   Running setup.py bdist_wheel for tabulate: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/2a/85/33/2f6da85d5f10614cbe5a625eab3b3aebfdf43e7b857f25f829
#   Running setup.py bdist_wheel for antlr4-python3-runtime: started
#   Running setup.py bdist_wheel for antlr4-python3-runtime: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/ef/f6/18/ad300e691236a3408a99edc750484b56e8d6b11b2c38eacb10
#   Running setup.py bdist_wheel for pycparser: started
#   Running setup.py bdist_wheel for pycparser: finished with status 'done'
#   Stored in directory: /root/.cache/pip/wheels/f2/9a/90/de94f8556265ddc9d9c8b271b0f63e57b26fb1d67a45564511
# Successfully built SecretStorage pathspec pyyaml tabulate antlr4-python3-runtime pycparser
# Installing collected packages: pytz, PyJWT, azure-common, chardet, idna, urllib3, requests, oauthlib, requests-oauthlib, isodate, msrest, pycparser, cffi, asn1crypto, cryptography, adal, msrestazure, azure-mgmt-containerregistry, backports.weakref, backports.tempfile, azure-nspkg, azure-cli-nspkg, argcomplete, humanfriendly, wheel, colorama, azure-mgmt-nspkg, azure-mgmt-resource, pyyaml, portalocker, applicationinsights, azure-cli-telemetry, pyopenssl, jmespath, tabulate, knack, pynacl, pyasn1, bcrypt, paramiko, antlr4-python3-runtime, azure-cli-core, azure-mgmt-storage, azure-storage-common, ruamel.yaml, azure-storage-blob, azure-mgmt-authorization, SecretStorage, ndg-httpsclient, azure-cli-command-modules-nspkg, azure-cli-profile, jsonpickle, docker-pycreds, websocket-client, docker, azure-graphrbac, azure-mgmt-keyvault, contextlib2, azure-storage-nspkg, pathspec, azureml-core, azureml-defaults, numpy, pandas, azureml.assets
#   Found existing installation: wheel 0.32.3
#     Uninstalling wheel-0.32.3:
#       Successfully uninstalled wheel-0.32.3
# Successfully installed PyJWT-1.7.1 SecretStorage-2.3.1 adal-1.2.0 antlr4-python3-runtime-4.7.1 applicationinsights-0.11.7 argcomplete-1.9.4 asn1crypto-0.24.0 azure-cli-command-modules-nspkg-2.0.2 azure-cli-core-2.0.52 azure-cli-nspkg-3.0.3 azure-cli-profile-2.1.2 azure-cli-telemetry-1.0.0 azure-common-1.1.16 azure-graphrbac-0.53.0 azure-mgmt-authorization-0.51.1 azure-mgmt-containerregistry-2.4.0 azure-mgmt-keyvault-1.1.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-resource-2.0.0 azure-mgmt-storage-3.1.0 azure-nspkg-3.0.2 azure-storage-blob-1.4.0 azure-storage-common-1.4.0 azure-storage-nspkg-3.1.0 azureml-core-1.0.2 azureml-defaults-1.0.2 azureml.assets-1.0.0 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.1.4 cffi-1.11.5 chardet-3.0.4 colorama-0.4.1 contextlib2-0.5.5 cryptography-2.4.2 docker-3.6.0 docker-pycreds-0.4.0 humanfriendly-4.17 idna-2.7 isodate-0.6.0 jmespath-0.9.3 jsonpickle-1.0 knack-0.5.1 msrest-0.6.2 msrestazure-0.5.1 ndg-httpsclient-0.5.1 numpy-1.15.4 oauthlib-2.1.0 pandas-0.23.4 paramiko-2.4.2 pathspec-0.5.9 portalocker-1.2.1 pyasn1-0.4.4 pycparser-2.19 pynacl-1.3.0 pyopenssl-18.0.0 pytz-2018.7 pyyaml-3.13 requests-2.20.1 requests-oauthlib-1.0.0 ruamel.yaml-0.15.51 tabulate-0.8.2 urllib3-1.23 websocket-client-0.54.0 wheel-0.30.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_90b783527e5b3ab85021085858275133
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
# Removing intermediate container b7c57e6df91f
#  ---> 2db4e7c451dc
# Step 9/13 : ENV PATH /azureml-envs/azureml_90b783527e5b3ab85021085858275133/bin:$PATH
#  ---> Running in ad7bb27af8b9
# Removing intermediate container ad7bb27af8b9
#  ---> 1a1ad45711f8
# Step 10/13 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_90b783527e5b3ab85021085858275133/lib:$LD_LIBRARY_PATH
#  ---> Running in 58c9d2bcbf74
# Removing intermediate container 58c9d2bcbf74
#  ---> d43ecb256b2c
# Step 11/13 : COPY azureml-setup/spark_cache.py azureml-setup/log4j.properties /azureml-setup/
#  ---> 2b4d0d42b1b0
# Step 12/13 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "https://mmlspark.azureedge.net/maven" "--packages" "com.microsoft.ml.spark:mmlspark_2.11:0.12" "--conf" "spark.app.name=Azure ML Experiment" "--conf" "spark.yarn.maxAppAttempts=1" "--driver-java-options" "-Dlog4j.configuration=file:./azureml-setup/log4j.properties" "--conf" "spark.eventLog.enabled=true" "--conf" "spark.eventLog.dir=./azureml-logs" /azureml-setup/spark_cache.py'; fi
#  ---> Running in 3723f302fd16
# Removing intermediate container 3723f302fd16
#  ---> 9bc2c6bde6b5
# Step 13/13 : CMD ["bash"]
#  ---> Running in e5ece3d6304c
# Removing intermediate container e5ece3d6304c
#  ---> a09b7b3573cb
# Successfully built a09b7b3573cb
# Successfully tagged predictiacrawjhhhpu.azurecr.io/azureml/azureml_75acd2b9baab5c8854bbbe177bd9fa4e:latest
# 2018/12/10 04:00:02 Executing step ID: acb_step_1. Working directory: '', Network: 'acb_default_network'
# 2018/12/10 04:00:02 Pushing image: predictiacrawjhhhpu.azurecr.io/azureml/azureml_75acd2b9baab5c8854bbbe177bd9fa4e:latest, attempt 1
# The push refers to repository [predictiacrawjhhhpu.azurecr.io/azureml/azureml_75acd2b9baab5c8854bbbe177bd9fa4e]
# cbc567097ea2: Preparing
# 38f7ffb61f9e: Preparing
# e7e434d3ca37: Preparing
# ce3009177650: Preparing
# b8e42bc561f4: Preparing
# e7ff3c8d56c2: Preparing
# ce619be2681d: Preparing
# db9d63ec4abf: Preparing
# 2fc9fc8da07e: Preparing
# 150ddd7a1544: Preparing
# 75b79e19929c: Preparing
# 4775b2f378bb: Preparing
# 883eafdbe580: Preparing
# 19d043c86cbc: Preparing
# 8823818c4748: Preparing
# e7ff3c8d56c2: Waiting
# ce619be2681d: Waiting
# db9d63ec4abf: Waiting
# 2fc9fc8da07e: Waiting
# 150ddd7a1544: Waiting
# 75b79e19929c: Waiting
# 4775b2f378bb: Waiting
# 883eafdbe580: Waiting
# 8823818c4748: Waiting
# e7e434d3ca37: Pushed
# cbc567097ea2: Pushed
# ce3009177650: Pushed
# b8e42bc561f4: Pushed
# e7ff3c8d56c2: Layer already exists
# 2fc9fc8da07e: Layer already exists
# ce619be2681d: Layer already exists
# 150ddd7a1544: Layer already exists
# 4775b2f378bb: Layer already exists
# 75b79e19929c: Layer already exists
# 883eafdbe580: Layer already exists
# 19d043c86cbc: Layer already exists
# 8823818c4748: Pushed
# 38f7ffb61f9e: Pushed
# db9d63ec4abf: Pushed
# latest: digest: sha256:107f1851bfce19d14fd8f3a490b502e52bf0b30d8d31419f120e71d6fd63b614 size: 3458
# 2018/12/10 04:01:18 Successfully pushed image: predictiacrawjhhhpu.azurecr.io/azureml/azureml_75acd2b9baab5c8854bbbe177bd9fa4e:latest
# 2018/12/10 04:01:18 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 128.098995)
# 2018/12/10 04:01:18 Populating digests for step ID: acb_step_0...
# 2018/12/10 04:01:20 Successfully populated digests for step ID: acb_step_0
# 2018/12/10 04:01:20 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 75.944878)
# The following dependencies were found:
# - image:
#     registry: predictiacrawjhhhpu.azurecr.io
#     repository: azureml/azureml_75acd2b9baab5c8854bbbe177bd9fa4e
#     tag: latest
#     digest: sha256:107f1851bfce19d14fd8f3a490b502e52bf0b30d8d31419f120e71d6fd63b614
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: 0.2.0
#     digest: sha256:bddfac8e9a4406c13f314cefefa24f3f67e959a8d8b26067096f7ade6f02ef12
#   git: {}
#
#
# Run ID: ca2 was successful after 3m32s
